# %%
import numpy as np

# %%
# %pip install torch torchvision torchaudio
# %pip install transformers
# %pip install langchain faiss-cpu sentence-transformers
# %pip install opencv-python matplotlib pandas numpy
# %pip install fastapi uvicorn
# %pip install gradio
# %pip install grad-cam
# %pip install scikit-learn
# Out:
# Collecting torch
#   Using cached torch-2.11.0-cp310-cp310-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Downloading torchvision-0.26.0-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.11.0-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.28.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from torch) (65.5.0)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch)
#   Using cached fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from torchvision) (2.2.6)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-12.2.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached markupsafe-3.0.3-cp310-cp310-win_amd64.whl.metadata (2.8 kB)
# Using cached torch-2.11.0-cp310-cp310-win_amd64.whl (114.5 MB)
# Downloading torchvision-0.26.0-cp310-cp310-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.7 MB ? eta -:--:--
#    ----------- ---------------------------- 1.0/3.7 MB 3.1 MB/s eta 0:00:01
#    -------------- ------------------------- 1.3/3.7 MB 2.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.1/3.7 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.1/3.7 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 3.2 MB/s  0:00:01
# Downloading torchaudio-2.11.0-cp310-cp310-win_amd64.whl (328 kB)
# Using cached fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Downloading pillow-12.2.0-cp310-cp310-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/7.1 MB 6.3 MB/s eta 0:00:01
#    ------------- -------------------------- 2.4/7.1 MB 5.8 MB/s eta 0:00:01
#    -------------------- ------------------- 3.7/7.1 MB 5.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.2/7.1 MB 6.1 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.1 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 6.3 MB/s  0:00:01
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading filelock-3.28.0-py3-none-any.whl (39 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp310-cp310-win_amd64.whl (15 kB)
# Installing collected packages: torchaudio, mpmath, sympy, pillow, networkx, MarkupSafe, fsspec, filelock, jinja2, torch, torchvision
#
#    ----------------------------------------  0/11 [torchaudio]
#    ----------------------------------------  0/11 [torchaudio]
#    --- ------------------------------------  1/11 [mpmath]
#    --- ------------------------------------  1/11 [mpmath]
#    --- ------------------------------------  1/11 [mpmath]
#    --- ------------------------------------  1/11 [mpmath]
#    --- ------------------------------------  1/11 [mpmath]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ------- --------------------------------  2/11 [sympy]
#    ---------- -----------------------------  3/11 [pillow]
#    ---------- -----------------------------  3/11 [pillow]
#    ---------- -----------------------------  3/11 [pillow]
#    ---------- -----------------------------  3/11 [pillow]
#    ---------- -----------------------------  3/11 [pillow]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    -------------- -------------------------  4/11 [networkx]
#    --------------------- ------------------  6/11 [fsspec]
#    --------------------- ------------------  6/11 [fsspec]
#    ----------------------------- ----------  8/11 [jinja2]
#    ----------------------------- ----------  8/11 [jinja2]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    -------------------------------- -------  9/11 [torch]
#    ------------------------------------ --- 10/11 [torchvision]
#    ------------------------------------ --- 10/11 [torchvision]
#    ------------------------------------ --- 10/11 [torchvision]
#    ------------------------------------ --- 10/11 [torchvision]
#    ------------------------------------ --- 10/11 [torchvision]
#    ------------------------------------ --- 10/11 [torchvision]
#    ------------------------------------ --- 10/11 [torchvision]
#    ------------------------------------ --- 10/11 [torchvision]
#    ---------------------------------------- 11/11 [torchvision]
#
# Successfully installed MarkupSafe-3.0.3 filelock-3.28.0 fsspec-2026.3.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.4.2 pillow-12.2.0 sympy-1.14.0 torch-2.11.0 torchaudio-2.11.0 torchvision-0.26.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting transformers
#   Downloading transformers-5.5.4-py3-none-any.whl.metadata (32 kB)
# Collecting huggingface-hub<2.0,>=1.5.0 (from transformers)
#   Downloading huggingface_hub-1.11.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from transformers) (26.1)
# Collecting pyyaml>=5.1 (from transformers)
#   Using cached pyyaml-6.0.3-cp310-cp310-win_amd64.whl.metadata (2.4 kB)
# Collecting regex>=2025.10.22 (from transformers)
#   Downloading regex-2026.4.4-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting typer (from transformers)
#   Using cached typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: filelock>=3.10.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.28.0)
# Requirement already satisfied: fsspec>=2023.5.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.3.0)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting httpx<1,>=0.23.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Collecting anyio (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading anyio-4.13.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting certifi (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: colorama in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.1)
# Collecting click>=8.2.1 (from typer->transformers)
#   Downloading click-8.3.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->transformers)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer->transformers)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->transformers)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer->transformers)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading transformers-5.5.4-py3-none-any.whl (10.2 MB)
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.2 MB 5.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/10.2 MB 4.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/10.2 MB 4.7 MB/s eta 0:00:02
#    ------------- -------------------------- 3.4/10.2 MB 4.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.2 MB 4.6 MB/s eta 0:00:02
#    ------------------- -------------------- 5.0/10.2 MB 4.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.8/10.2 MB 4.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.3/10.2 MB 4.0 MB/s eta 0:00:01
#    --------------------------- ------------ 7.1/10.2 MB 3.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.6/10.2 MB 3.8 MB/s eta 0:00:01
#    ------------------------------- -------- 8.1/10.2 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.9/10.2 MB 3.7 MB/s eta 0:00:01
#    -------------------------------------- - 10.0/10.2 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 3.8 MB/s  0:00:02
# Downloading huggingface_hub-1.11.0-py3-none-any.whl (645 kB)
#    ---------------------------------------- 0.0/645.5 kB ? eta -:--:--
#    ---------------------------------------- 645.5/645.5 kB 6.1 MB/s  0:00:00
# Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.7 MB 4.2 MB/s eta 0:00:01
#    ------------------- -------------------- 1.8/3.7 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.1/3.7 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 5.2 MB/s  0:00:00
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached pyyaml-6.0.3-cp310-cp310-win_amd64.whl (158 kB)
# Downloading regex-2026.4.4-cp310-cp310-win_amd64.whl (278 kB)
# Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading anyio-4.13.0-py3-none-any.whl (114 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Using cached typer-0.24.1-py3-none-any.whl (56 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.3.2-py3-none-any.whl (108 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: tqdm, shellingham, safetensors, regex, pyyaml, mdurl, idna, hf-xet, h11, click, certifi, annotated-doc, markdown-it-py, httpcore, anyio, rich, httpx, typer, huggingface-hub, tokenizers, transformers
#
#    --- ------------------------------------  2/21 [safetensors]
#    ------- --------------------------------  4/21 [pyyaml]
#    ----------- ----------------------------  6/21 [idna]
#    ------------- --------------------------  7/21 [hf-xet]
#    ----------------- ----------------------  9/21 [click]
#    ---------------------- ----------------- 12/21 [markdown-it-py]
#    ---------------------- ----------------- 12/21 [markdown-it-py]
#    ------------------------ --------------- 13/21 [httpcore]
#    ------------------------ --------------- 13/21 [httpcore]
#    ------------------------ --------------- 13/21 [httpcore]
#    -------------------------- ------------- 14/21 [anyio]
#    ---------------------------- ----------- 15/21 [rich]
#    ---------------------------- ----------- 15/21 [rich]
#    ---------------------------- ----------- 15/21 [rich]
#    ---------------------------- ----------- 15/21 [rich]
#    ---------------------------- ----------- 15/21 [rich]
#    ---------------------------- ----------- 15/21 [rich]
#    ------------------------------ --------- 16/21 [httpx]
#    ------------------------------ --------- 16/21 [httpx]
#    -------------------------------- ------- 17/21 [typer]
#    -------------------------------- ------- 17/21 [typer]
#    ---------------------------------- ----- 18/21 [huggingface-hub]
#    ---------------------------------- ----- 18/21 [huggingface-hub]
#    ---------------------------------- ----- 18/21 [huggingface-hub]
#    ---------------------------------- ----- 18/21 [huggingface-hub]
#    ---------------------------------- ----- 18/21 [huggingface-hub]
#    ---------------------------------- ----- 18/21 [huggingface-hub]
#    ---------------------------------- ----- 18/21 [huggingface-hub]
#    ---------------------------------- ----- 18/21 [huggingface-hub]
#    ------------------------------------ --- 19/21 [tokenizers]
#    ------------------------------------ --- 19/21 [tokenizers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    -------------------------------------- - 20/21 [transformers]
#    ---------------------------------------- 21/21 [transformers]
#
# Successfully installed annotated-doc-0.0.4 anyio-4.13.0 certifi-2026.2.25 click-8.3.2 h11-0.16.0 hf-xet-1.4.3 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-1.11.0 idna-3.11 markdown-it-py-4.0.0 mdurl-0.1.2 pyyaml-6.0.3 regex-2026.4.4 rich-15.0.0 safetensors-0.7.0 shellingham-1.5.4 tokenizers-0.22.2 tqdm-4.67.3 transformers-5.5.4 typer-0.24.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting langchain
#   Downloading langchain-1.2.15-py3-none-any.whl.metadata (5.8 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.2-cp310-cp310-win_amd64.whl.metadata (7.6 kB)
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.4.1-py3-none-any.whl.metadata (17 kB)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain)
#   Downloading langchain_core-1.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph<1.2.0,>=1.1.5 (from langchain)
#   Downloading langgraph-1.1.7-py3-none-any.whl.metadata (8.0 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Downloading pydantic-2.13.2-py3-none-any.whl.metadata (108 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading langsmith-0.7.32-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_checkpoint-4.0.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.9 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_prebuilt-1.0.9-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_sdk-0.3.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached xxhash-3.6.0-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading ormsgpack-1.12.2-cp310-cp310-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading orjson-3.11.8-cp310-cp310-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests>=2.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading zstandard-0.25.0-cp310-cp310-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.13.0)
# Requirement already satisfied: certifi in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading pydantic_core-2.46.2-cp310-cp310-win_amd64.whl.metadata (6.7 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from faiss-cpu) (2.2.6)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from sentence-transformers) (5.5.4)
# Requirement already satisfied: huggingface-hub>=0.23.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from sentence-transformers) (1.11.0)
# Requirement already satisfied: torch>=1.11.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from sentence-transformers) (2.11.0)
# Collecting scikit-learn>=0.22.0 (from sentence-transformers)
#   Downloading scikit_learn-1.7.2-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting scipy>=1.0.0 (from sentence-transformers)
#   Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: tqdm>=4.0.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: regex>=2025.10.22 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.28.0)
# Requirement already satisfied: fsspec>=2023.5.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.4.3)
# Collecting charset_normalizer<4,>=2 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading charset_normalizer-3.4.7-cp310-cp310-win_amd64.whl.metadata (41 kB)
# Collecting urllib3<3,>=1.26 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting joblib>=1.2.0 (from scikit-learn>=0.22.0->sentence-transformers)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.22.0->sentence-transformers)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: setuptools<82 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (65.5.0)
# Requirement already satisfied: sympy>=1.13.3 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from tqdm>=4.0.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from rich>=12.3.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.20.0)
# ...
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: starlette<2.0,>=0.40.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from gradio) (1.0.0)
# Collecting tomlkit<0.15.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.14.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from gradio) (0.24.1)
# Requirement already satisfied: typing-extensions~=4.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from gradio) (0.44.0)
# Requirement already satisfied: fsspec in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from gradio-client==2.4.1->gradio) (2026.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from anyio<5.0,>=3.0->gradio) (1.3.1)
# Requirement already satisfied: idna>=2.8 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Requirement already satisfied: typing-inspection>=0.4.2 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.28.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.4.3)
# Requirement already satisfied: tqdm>=4.42.1 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from pandas<4.0,>=1.0->gradio) (2026.1)
# Requirement already satisfied: annotated-types>=0.6.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.2 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from pydantic<=3.0,>=2.0->gradio) (2.46.2)
# Requirement already satisfied: click>=8.2.1 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio) (15.0.0)
# Requirement already satisfied: colorama in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from click>=8.2.1->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Downloading gradio-6.12.0-py3-none-any.whl (19.6 MB)
#    ---------------------------------------- 0.0/19.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/19.6 MB 4.2 MB/s eta 0:00:05
#    -- ------------------------------------- 1.0/19.6 MB 3.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 2.1/19.6 MB 4.1 MB/s eta 0:00:05
#    ------ --------------------------------- 3.1/19.6 MB 4.3 MB/s eta 0:00:04
#    -------- ------------------------------- 4.2/19.6 MB 4.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 5.2/19.6 MB 4.5 MB/s eta 0:00:04
#    ------------- -------------------------- 6.6/19.6 MB 4.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 7.9/19.6 MB 5.0 MB/s eta 0:00:03
#    ------------------ --------------------- 9.2/19.6 MB 5.1 MB/s eta 0:00:03
#    --------------------- ------------------ 10.5/19.6 MB 5.3 MB/s eta 0:00:02
#    ------------------------ --------------- 12.1/19.6 MB 5.5 MB/s eta 0:00:02
#    --------------------------- ------------ 13.6/19.6 MB 5.7 MB/s eta 0:00:02
#    ------------------------------ --------- 14.9/19.6 MB 5.8 MB/s eta 0:00:01
#    --------------------------------- ------ 16.5/19.6 MB 5.9 MB/s eta 0:00:01
#    ------------------------------------ --- 18.1/19.6 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.6 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 19.6/19.6 MB 6.1 MB/s  0:00:03
# Downloading gradio_client-2.4.1-py3-none-any.whl (59 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading hf_gradio-0.4.0-py3-none-any.whl (4.5 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading python_multipart-0.0.26-py3-none-any.whl (28 kB)
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading tomlkit-0.14.0-py3-none-any.whl (39 kB)
# Downloading brotli-1.2.0-cp310-cp310-win_amd64.whl (369 kB)
# Installing collected packages: pydub, brotli, tomlkit, semantic-version, python-multipart, groovy, safehttpx, gradio-client, hf-gradio, gradio
#
#    ------------------------------------ ---  9/10 [gradio]
#    ------------------------------------ ---  9/10 [gradio]
#    ------------------------------------ ---  9/10 [gradio]
#    ------------------------------------ ---  9/10 [gradio]
#    ------------------------------------ ---  9/10 [gradio]
#    ------------------------------------ ---  9/10 [gradio]
#    ------------------------------------ ---  9/10 [gradio]
#    ------------------------------------ ---  9/10 [gradio]
#    ------------------------------------ ---  9/10 [gradio]
#    ------------------------------------ ---  9/10 [gradio]
#    ---------------------------------------- 10/10 [gradio]
#
# Successfully installed brotli-1.2.0 gradio-6.12.0 gradio-client-2.4.1 groovy-0.1.2 hf-gradio-0.4.0 pydub-0.25.1 python-multipart-0.0.26 safehttpx-0.1.7 semantic-version-2.10.0 tomlkit-0.14.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting grad-cam
#   Downloading grad-cam-1.5.5.tar.gz (7.8 MB)
#      ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#      - -------------------------------------- 0.3/7.8 MB ? eta -:--:--
#      ---- ----------------------------------- 0.8/7.8 MB 2.6 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.0/7.8 MB 2.5 MB/s eta 0:00:03
#      --------- ------------------------------ 1.8/7.8 MB 2.5 MB/s eta 0:00:03
#      ---------- ----------------------------- 2.1/7.8 MB 2.5 MB/s eta 0:00:03
#      ------------- -------------------------- 2.6/7.8 MB 2.4 MB/s eta 0:00:03
#      ---------------- ----------------------- 3.1/7.8 MB 2.4 MB/s eta 0:00:02
#      ------------------ --------------------- 3.7/7.8 MB 2.4 MB/s eta 0:00:02
#      --------------------- ------------------ 4.2/7.8 MB 2.4 MB/s eta 0:00:02
#      ------------------------ --------------- 4.7/7.8 MB 2.4 MB/s eta 0:00:02
#      -------------------------- ------------- 5.2/7.8 MB 2.5 MB/s eta 0:00:02
#      ----------------------------- ---------- 5.8/7.8 MB 2.5 MB/s eta 0:00:01
#      --------------------------------- ------ 6.6/7.8 MB 2.5 MB/s eta 0:00:01
#      ------------------------------------ --- 7.1/7.8 MB 2.5 MB/s eta 0:00:01
#      ---------------------------------------- 7.8/7.8 MB 2.6 MB/s  0:00:03
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from grad-cam) (2.2.6)
# Requirement already satisfied: Pillow in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from grad-cam) (12.2.0)
# Requirement already satisfied: torch>=1.7.1 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from grad-cam) (2.11.0)
# Requirement already satisfied: torchvision>=0.8.2 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from grad-cam) (0.26.0)
# Collecting ttach (from grad-cam)
#   Downloading ttach-0.0.3-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: tqdm in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from grad-cam) (4.67.3)
# Requirement already satisfied: opencv-python in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from grad-cam) (4.13.0.92)
# Requirement already satisfied: matplotlib in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from grad-cam) (3.10.8)
# Requirement already satisfied: scikit-learn in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from grad-cam) (1.7.2)
# Requirement already satisfied: filelock in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from torch>=1.7.1->grad-cam) (3.28.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from torch>=1.7.1->grad-cam) (4.15.0)
# Requirement already satisfied: setuptools<82 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from torch>=1.7.1->grad-cam) (65.5.0)
# Requirement already satisfied: sympy>=1.13.3 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from torch>=1.7.1->grad-cam) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from torch>=1.7.1->grad-cam) (3.4.2)
# Requirement already satisfied: jinja2 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from torch>=1.7.1->grad-cam) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from torch>=1.7.1->grad-cam) (2026.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.7.1->grad-cam) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from jinja2->torch>=1.7.1->grad-cam) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from matplotlib->grad-cam) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from matplotlib->grad-cam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from matplotlib->grad-cam) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from matplotlib->grad-cam) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from matplotlib->grad-cam) (26.1)
# Requirement already satisfied: pyparsing>=3 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from matplotlib->grad-cam) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from matplotlib->grad-cam) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->grad-cam) (1.17.0)
# Requirement already satisfied: scipy>=1.8.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from scikit-learn->grad-cam) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from scikit-learn->grad-cam) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from scikit-learn->grad-cam) (3.6.0)
# Requirement already satisfied: colorama in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from tqdm->grad-cam) (0.4.6)
# Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Building wheels for collected packages: grad-cam
#   Building wheel for grad-cam (pyproject.toml): started
#   Building wheel for grad-cam (pyproject.toml): finished with status 'done'
#   Created wheel for grad-cam: filename=grad_cam-1.5.5-py3-none-any.whl size=44340 sha256=191bd77e69130c9f6f8e599328f16d546bf529a2458eeaaa9990f6100a515819
#   Stored in directory: c:\users\sande\appdata\local\pip\cache\wheels\3d\b6\be\e13cccebb2aa8855f678b02ad449e803de1dfbe75853c34b3e
# Successfully built grad-cam
# Installing collected packages: ttach, grad-cam
#
#    ---------------------------------------- 2/2 [grad-cam]
#
# Successfully installed grad-cam-1.5.5 ttach-0.0.3
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in a:\programming-language-\medical-project\coding-part\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
